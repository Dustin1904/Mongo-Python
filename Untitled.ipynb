# %%
#Abrir una base de datos para "Leer lo que contiene"
import pymongo
#import pandas as pd
from pymongo import MongoClient
client = MongoClient('127.0.0.1',27017)
db = client['DeberAnalisis']
db.create_collection('Bases')
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'DeberAnalisis'), 'Bases')

# %%
from pymongo import MongoClient
client = MongoClient('127.0.0.1',27017)
print(client.list_database_names())
# Out:
# ['DeberAnalisis', 'Fornite', 'Juegos', 'Peliculas', 'admin', 'config', 'local']

# %%
database = client.DeberAnalisis
collection = database.list_collection_names()
print(collection)
# Out:
# ['Bases']

# %%
import pymongo
import pandas as pd
from pymongo import MongoClient

# Conectar a MongoDB
client = MongoClient('127.0.0.1', 27017)
db = client['DeberAnalisis']
mi_coleccion = db['Base']

# Cargar el archivo CSV en un DataFrame
archivo_csv = 'Fortnite Statistics.csv'
df = pd.read_csv(archivo_csv)

# Convertir el DataFrame a una lista de diccionarios (cada fila es un diccionario)
datos_para_insertar = df.to_dict(orient='records')

# Insertar los documentos en la colección
mi_coleccion.insert_many(datos_para_insertar)
# Out:
# InsertManyResult([ObjectId('6585bef52f798a280a3d460a'), ObjectId('6585bef52f798a280a3d460b'), ObjectId('6585bef52f798a280a3d460c'), ObjectId('6585bef52f798a280a3d460d'), ObjectId('6585bef52f798a280a3d460e'), ObjectId('6585bef52f798a280a3d460f'), ObjectId('6585bef52f798a280a3d4610'), ObjectId('6585bef52f798a280a3d4611'), ObjectId('6585bef52f798a280a3d4612'), ObjectId('6585bef52f798a280a3d4613'), ObjectId('6585bef52f798a280a3d4614'), ObjectId('6585bef52f798a280a3d4615'), ObjectId('6585bef52f798a280a3d4616'), ObjectId('6585bef52f798a280a3d4617'), ObjectId('6585bef52f798a280a3d4618'), ObjectId('6585bef52f798a280a3d4619'), ObjectId('6585bef52f798a280a3d461a'), ObjectId('6585bef52f798a280a3d461b'), ObjectId('6585bef52f798a280a3d461c'), ObjectId('6585bef52f798a280a3d461d'), ObjectId('6585bef52f798a280a3d461e'), ObjectId('6585bef52f798a280a3d461f'), ObjectId('6585bef52f798a280a3d4620'), ObjectId('6585bef52f798a280a3d4621'), ObjectId('6585bef52f798a280a3d4622'), ObjectId('6585bef52f798a280a3d
# ...

# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
client = MongoClient()
db = client.DeberAnalisis
collection = db.Base
data1 = pd.DataFrame(list(collection.find()))#.drop('_id', axis=1)

# %%
data1
# Out:
#                          _id    Date Time of Day Placed Mental State  \
# 0   6585bef52f798a280a3d460a    4/10     6:00 PM     27        sober
# 1   6585bef52f798a280a3d460b    4/10     6:00 PM     45        sober
# 2   6585bef52f798a280a3d460c    4/10     6:00 PM     38         high
# 3   6585bef52f798a280a3d460d    4/10     7:00 PM     30         high
# 4   6585bef52f798a280a3d460e    4/10     7:00 PM     16         high
# ..                       ...     ...         ...    ...          ...
# 83  6585bef52f798a280a3d465d  17-Apr    12:00 AM     24         high
# 84  6585bef52f798a280a3d465e  17-Apr     1:00 PM     30        sober
# 85  6585bef52f798a280a3d465f  17-Apr     2:00 PM     18        sober
# 86  6585bef52f798a280a3d4660  17-Apr     2:00 PM     39        sober
# 87  6585bf1c2f798a280a3d4662   19/03     8:58 PM     50         Alto
#
#    Eliminations Assists Revives Accuracy Hits Head Shots Distance Traveled  \
# ...

# %%
ingreso_dato=[{
    "Date":"19/03",
    "Time of Day":"8:58 PM",
    "Placed":"50",
    "Mental State":"Alto",
    "Eliminations":"5",
    "Assists":"10",
    "Revives":"3",
    "Accuracy":"50%",
    "Hits":"50",
    "Head Shots":"5",
    "Distance Traveled":"550.50",
    "Materials Gathered":"5000",
    "Materials Used":"50",
    "Damage Taken":"500",
    "Damage to Players":"500",
    "Damage to Structures":"500",
},{"Date":"xd",
    "Time of Day":"xd",
    "Placed":"xd",
    "Mental State":"xd",
    "Eliminations":"xd",
    "Assists":"xd",
    "Revives":"xd",
    "Accuracy":"xd",
    "Hits":"xd",
    "Head Shots":"xd",
    "Distance Traveled":"xd",
    "Materials Gathered":"xd",
    "Materials Used":"xd",
    "Damage Taken":"xd",
    "Damage to Players":"xd",
    "Damage to Structures":"xd",}]
resultado=collection.insert_many(ingreso_dato)

# %%
from bson.objectid import ObjectId
eliminar={'_id':ObjectId('6585bf1c2f798a280a3d4663')}
collection.delete_one(eliminar)
# Out:
# DeleteResult({'n': 1, 'ok': 1.0}, acknowledged=True)

# %%
actualizar={'_id':ObjectId('6585bf1c2f798a280a3d4662')}
cambiar_valores={'$set':{'Assists':'xdxd'}}
collection.update_one(actualizar, cambiar_valores)
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
